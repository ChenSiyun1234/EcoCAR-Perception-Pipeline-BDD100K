# %% [markdown]
# # Stage2 / 02 — Train the **raw** stage2 DETR-lane branch (1-class)
#
# Trains `stage2/configs/detrlane_vehicle1c.yaml`:
# - DETR-style lane head (stage2 architecture)
# - 1-class detection (same taxonomy as stage1)
# - **no** warm-start, **no** distillation, **no** gradient balancing
#
# This is the control-group run. A/B against stage1/checkpoints/yolopv2_best_row
# measures the pure effect of swapping in the stage2 lane head.

# %%
from google.colab import drive; drive.mount('/content/drive')
import os, sys
REPO_ROOT = '/content/drive/MyDrive/EcoCAR/yolop_vehicle_lane'
os.chdir(REPO_ROOT); sys.path.insert(0, REPO_ROOT)
# !pip install -q yacs tqdm opencv-python-headless scipy

# %%
from stage2.lib.train_helpers import run_stage2_training

cfg = run_stage2_training(
    yaml_path=os.path.join(REPO_ROOT, 'stage2', 'configs', 'detrlane_vehicle1c.yaml'),
    repo_root=REPO_ROOT,
    ecocar_root='/content/drive/MyDrive/EcoCAR',
)
