# %% [markdown]
# # Stage2 / 03 — Train with WARM-START from stage1 best-row
#
# Starts the student from stage1/yolopv2_best_row/best.pth. Two flavours:
# - `detrlane_vehicle1c_warmstart.yaml` — same 1-class taxonomy (direct A/B vs stage1)
# - `detrlane_vehicle3c_warmstart.yaml` — 3-class extension (vehicle + moto + bike),
#   with class-remapped warm-start (vehicle row copied, new class rows initialised fresh)
#
# Switch `CONFIG` to pick a variant.

# %%
from google.colab import drive; drive.mount('/content/drive')
import os, sys
REPO_ROOT = '/content/drive/MyDrive/EcoCAR/yolop_vehicle_lane'
os.chdir(REPO_ROOT); sys.path.insert(0, REPO_ROOT)
# !pip install -q yacs tqdm opencv-python-headless scipy

# %%
from stage2.lib.train_helpers import run_stage2_training

# Flip between '1c' (same taxonomy as stage1) and '3c' (extended taxonomy).
CONFIG = 'detrlane_vehicle3c_warmstart.yaml'

cfg = run_stage2_training(
    yaml_path=os.path.join(REPO_ROOT, 'stage2', 'configs', CONFIG),
    repo_root=REPO_ROOT,
    ecocar_root='/content/drive/MyDrive/EcoCAR',
)
