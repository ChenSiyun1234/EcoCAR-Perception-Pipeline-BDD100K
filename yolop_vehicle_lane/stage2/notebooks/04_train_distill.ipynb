# %% [markdown]
# # Stage2 / 04 — Train with WARM-START + DETECTION DISTILLATION
#
# Adds a detection-branch KD signal (box + obj + shared-vehicle class)
# from the frozen stage1 teacher on top of the warm-start run.
#
# A/B against notebook 03 isolates the distillation effect.

# %%
from google.colab import drive; drive.mount('/content/drive')
import os, sys
REPO_ROOT = '/content/drive/MyDrive/EcoCAR/yolop_vehicle_lane'
os.chdir(REPO_ROOT); sys.path.insert(0, REPO_ROOT)
# !pip install -q yacs tqdm opencv-python-headless scipy

# %%
from stage2.lib.train_helpers import run_stage2_training

cfg = run_stage2_training(
    yaml_path=os.path.join(REPO_ROOT, 'stage2', 'configs',
                           'detrlane_vehicle3c_distill.yaml'),
    repo_root=REPO_ROOT,
    ecocar_root='/content/drive/MyDrive/EcoCAR',
)
