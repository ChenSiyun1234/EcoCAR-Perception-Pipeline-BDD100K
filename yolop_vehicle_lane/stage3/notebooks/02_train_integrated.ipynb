# %% [markdown]
# # Stage3 / 02 — Train the integrated model
#
# Runs `stage2.lib.train_helpers.run_stage2_training` against the
# stage3 YAML materialized by stage3/00. Stage3 is a short fine-tune
# on top of the stage2 winner — keep `END_EPOCH` modest.

# %%
from google.colab import drive; drive.mount('/content/drive')
import os, sys, glob
REPO_ROOT = '/content/drive/MyDrive/EcoCAR/yolop_vehicle_lane'
os.chdir(REPO_ROOT); sys.path.insert(0, REPO_ROOT)
# !pip install -q yacs tqdm opencv-python-headless scipy

# %%
from stage2.lib.train_helpers import run_stage2_training

candidates = sorted(glob.glob(os.path.join(REPO_ROOT, 'stage3', 'configs', 'integrated_from_*.yaml')))
assert candidates, 'Run stage3/00 first.'
YAML = candidates[-1]
print('Training stage3 with', YAML)
run_stage2_training(yaml_path=YAML,
                    repo_root=REPO_ROOT,
                    ecocar_root='/content/drive/MyDrive/EcoCAR')
